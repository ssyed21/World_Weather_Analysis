# %%
import random
import numpy as np
import timeit
import matplotlib.pyplot as plt
import pandas as pd
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from datetime import datetime

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "e0a89900dae2feef3c7dfc2d3d121555"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | matay
# Processing Record 3 of Set 1 | moultonborough
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | yaan
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | billings
# Processing Record 8 of Set 1 | homer
# Processing Record 9 of Set 1 | fort saint john
# City not found. Skipping
# Processing Record 10 of Set 1 | pangai
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | mendoza
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | nurota
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | north bend
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | pulandian
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | dukat
# Processing Record 30 of Set 1 | loandjili
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | bage
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | tautira
# Processing Record 36 of Set 1 | flinders
# Processing Record 37 of Set 1 | marawi
# Processing Record 38 of Set 1 | carolina
# Processing Record 39 of Set 1 | at-bashi
# Processing Record 40 of Set 1 | malinovoye ozero
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | semey
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | torrington
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | biak
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | abalak
# Processing Record 2 of Set 2 | bom jesus
# Processing Record 3 of Set 2 | yining
# Processing Record 4 of Set 2 | katherine
# Processing Record 5 of Set 2 | bonthe
# Processing Record 6 of Set 2 | chernushka
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | macapa
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | camalu
# Processing Record 11 of Set 2 | tuatapere
# Processing Record 12 of Set 2 | northam
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | geraldton
# Processing Record 17 of Set 2 | preobrazheniye
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | lompoc
# Processing Record 20 of Set 2 | taunggyi
# Processing Record 21 of Set 2 | derzhavinsk
# Processing Record 22 of Set 2 | itaituba
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | taltal
# Processing Record 25 of Set 2 | dutlwe
# Processing Record 26 of Set 2 | salalah
# Processing Record 27 of Set 2 | buala
# Processing Record 28 of Set 2 | caldas novas
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | punta de piedra
# Processing Record 31 of Set 2 | svetlyy
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 33 of Set 2 | aykhal
# Processing Record 34 of Set 2 | dwarka
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping
# Processing Record 37 of Set 2 | minab
# Processing Record 38 of Set 2 | mogwase
# Processing Record 39 of Set 2 | araouane
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | hanover
# Processing Record 43 of Set 2 | umea
# Processing Record 44 of Set 2 | hualmay
# Processing Record 45 of Set 2 | puerto penasco
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | nikolskoye
# Processing Record 50 of Set 2 | mahebourg
# Processing Record 1 of Set 3 | strezhevoy
# Processing Record 2 of Set 3 | uk
# City not found. Skipping
# Processing Record 3 of Set 3 | mount isa
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | miyang
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | kapit
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | veraval
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | tawau
# Processing Record 13 of Set 3 | tumarbong
# Processing Record 14 of Set 3 | egvekinot
# Processing Record 15 of Set 3 | porto novo
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | bac can
# City not found. Skipping
# Processing Record 18 of Set 3 | konstantinovka
# Processing Record 19 of Set 3 | asfi
# Processing Record 20 of Set 3 | codrington
# Processing Record 21 of Set 3 | brae
# Processing Record 22 of Set 3 | murree
# Processing Record 23 of Set 3 | aktas
# Processing Record 24 of Set 3 | el wasta
# City not found. Skipping
# Processing Record 25 of Set 3 | chagda
# City not found. Skipping
# Processing Record 26 of Set 3 | kamenskoye
# City not found. Skipping
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | innisfail
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | spencer
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | barra do garcas
# Processing Record 35 of Set 3 | palabuhanratu
# City not found. Skipping
# Processing Record 36 of Set 3 | wamba
# Processing Record 37 of Set 3 | rawson
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | birobidzhan
# Processing Record 40 of Set 3 | ballina
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping
# Processing Record 42 of Set 3 | luoyang
# Processing Record 43 of Set 3 | pekan nenas
# Processing Record 44 of Set 3 | namatanai
# Processing Record 45 of Set 3 | leningradskiy
# Processing Record 46 of Set 3 | tiarei
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping
# Processing Record 48 of Set 3 | khambhaliya
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 50 of Set 3 | menongue
# Processing Record 1 of Set 4 | kirakira
# Processing Record 2 of Set 4 | vaitupu
# City not found. Skipping
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping
# Processing Record 4 of Set 4 | camopi
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | praia da vitoria
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | amga
# Processing Record 13 of Set 4 | salinopolis
# Processing Record 14 of Set 4 | poum
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | dharchula
# Processing Record 17 of Set 4 | inirida
# Processing Record 18 of Set 4 | baruun-urt
# Processing Record 19 of Set 4 | bluff
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | mogadishu
# Processing Record 22 of Set 4 | todos santos
# Processing Record 23 of Set 4 | wilmington
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | rostovka
# Processing Record 26 of Set 4 | ruatoria
# City not found. Skipping
# Processing Record 27 of Set 4 | kloulklubed
# Processing Record 28 of Set 4 | karratha
# Processing Record 29 of Set 4 | bayevo
# Processing Record 30 of Set 4 | eyrarbakki
# Processing Record 31 of Set 4 | hay river
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | tamiahua
# Processing Record 34 of Set 4 | rogers
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | hovd
# Processing Record 37 of Set 4 | san carlos de bariloche
# Processing Record 38 of Set 4 | kokopo
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 41 of Set 4 | kashi
# Processing Record 42 of Set 4 | ambulu
# Processing Record 43 of Set 4 | bunia
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | dzhusaly
# City not found. Skipping
# Processing Record 46 of Set 4 | atar
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | mayo
# Processing Record 50 of Set 4 | freeport
# Processing Record 1 of Set 5 | iglesias
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | padang
# Processing Record 4 of Set 5 | lazaro cardenas
# Processing Record 5 of Set 5 | kihei
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | mecca
# Processing Record 8 of Set 5 | kalmunai
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | goderich
# Processing Record 11 of Set 5 | novopokrovka
# Processing Record 12 of Set 5 | polewali
# Processing Record 13 of Set 5 | cuxhaven
# Processing Record 14 of Set 5 | cap malheureux
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | ostrovnoy
# Processing Record 18 of Set 5 | carballo
# Processing Record 19 of Set 5 | sambava
# Processing Record 20 of Set 5 | ternate
# Processing Record 21 of Set 5 | gizo
# Processing Record 22 of Set 5 | kamaishi
# Processing Record 23 of Set 5 | vilhena
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | loikaw
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | isiro
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | santa isabel do rio negro
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | seoul
# Processing Record 35 of Set 5 | chupa
# Processing Record 36 of Set 5 | concarneau
# Processing Record 37 of Set 5 | aswan
# Processing Record 38 of Set 5 | thunder bay
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | afmadu
# City not found. Skipping
# Processing Record 41 of Set 5 | puerto ayora
# Processing Record 42 of Set 5 | medina del campo
# Processing Record 43 of Set 5 | porto velho
# Processing Record 44 of Set 5 | izalco
# Processing Record 45 of Set 5 | pundaguitan
# Processing Record 46 of Set 5 | black river
# Processing Record 47 of Set 5 | tabou
# Processing Record 48 of Set 5 | elko
# Processing Record 49 of Set 5 | mildura
# Processing Record 50 of Set 5 | sabang
# Processing Record 1 of Set 6 | limbang
# Processing Record 2 of Set 6 | ouesso
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | atbasar
# Processing Record 6 of Set 6 | labutta
# City not found. Skipping
# Processing Record 7 of Set 6 | sinnamary
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | paramonga
# Processing Record 10 of Set 6 | telfs
# Processing Record 11 of Set 6 | pereslavl-zalesskiy
# Processing Record 12 of Set 6 | jalu
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | waihi beach
# Processing Record 15 of Set 6 | armacao de pera
# Processing Record 16 of Set 6 | salme
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | nades
# Processing Record 19 of Set 6 | nantucket
# Processing Record 20 of Set 6 | narsaq
# Processing Record 21 of Set 6 | grindavik
# Processing Record 22 of Set 6 | uwayl
# City not found. Skipping
# Processing Record 23 of Set 6 | adre
# Processing Record 24 of Set 6 | avarua
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | kasama
# Processing Record 27 of Set 6 | cheuskiny
# City not found. Skipping
# Processing Record 28 of Set 6 | jonkoping
# Processing Record 29 of Set 6 | kholtoson
# Processing Record 30 of Set 6 | khatanga
# Processing Record 31 of Set 6 | ambunti
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | sajanan
# Processing Record 34 of Set 6 | kenai
# Processing Record 35 of Set 6 | makakilo city
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | rosario
# Processing Record 39 of Set 6 | saint-joseph
# Processing Record 40 of Set 6 | cozumel
# Processing Record 41 of Set 6 | pangnirtung
# Processing Record 42 of Set 6 | palu
# Processing Record 43 of Set 6 | sorland
# Processing Record 44 of Set 6 | anda
# Processing Record 45 of Set 6 | caravelas
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | waling
# Processing Record 48 of Set 6 | muros
# Processing Record 49 of Set 6 | kerouane
# Processing Record 50 of Set 6 | taguisa
# Processing Record 1 of Set 7 | san antonio
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | cotonou
# Processing Record 4 of Set 7 | kondinskoye
# Processing Record 5 of Set 7 | burnie
# Processing Record 6 of Set 7 | comodoro rivadavia
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | healdsburg
# Processing Record 9 of Set 7 | kpandae
# Processing Record 10 of Set 7 | fort nelson
# Processing Record 11 of Set 7 | baykit
# Processing Record 12 of Set 7 | oranjestad
# Processing Record 13 of Set 7 | tiznit
# Processing Record 14 of Set 7 | anori
# Processing Record 15 of Set 7 | thinadhoo
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | orotukan
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping
# Processing Record 19 of Set 7 | la macarena
# Processing Record 20 of Set 7 | mugur-aksy
# Processing Record 21 of Set 7 | el dorado
# Processing Record 22 of Set 7 | mishelevka
# Processing Record 23 of Set 7 | trairi
# Processing Record 24 of Set 7 | juegang
# Processing Record 25 of Set 7 | challans
# Processing Record 26 of Set 7 | san angelo
# Processing Record 27 of Set 7 | kabanjahe
# Processing Record 28 of Set 7 | santa cruz
# Processing Record 29 of Set 7 | san policarpo
# Processing Record 30 of Set 7 | bodden town
# Processing Record 31 of Set 7 | severo-kurilsk
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | chiang rai
# Processing Record 34 of Set 7 | cumberland
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | umzimvubu
# City not found. Skipping
# Processing Record 38 of Set 7 | svobodnyy
# Processing Record 39 of Set 7 | nago
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | nizhniy ingash
# Processing Record 42 of Set 7 | moerai
# Processing Record 43 of Set 7 | singaraja
# Processing Record 44 of Set 7 | kawalu
# Processing Record 45 of Set 7 | vestmannaeyjar
# Processing Record 46 of Set 7 | sunrise manor
# Processing Record 47 of Set 7 | tuensang
# Processing Record 48 of Set 7 | syamzha
# Processing Record 49 of Set 7 | bilibino
# Processing Record 50 of Set 7 | lagoa
# Processing Record 1 of Set 8 | axim
# Processing Record 2 of Set 8 | fez
# Processing Record 3 of Set 8 | moree
# Processing Record 4 of Set 8 | george
# Processing Record 5 of Set 8 | marovoay
# Processing Record 6 of Set 8 | hobyo
# Processing Record 7 of Set 8 | prince albert
# Processing Record 8 of Set 8 | ketchikan
# Processing Record 9 of Set 8 | shingu
# Processing Record 10 of Set 8 | progreso
# Processing Record 11 of Set 8 | botou
# Processing Record 12 of Set 8 | sistranda
# Processing Record 13 of Set 8 | penzance
# Processing Record 14 of Set 8 | faya
# Processing Record 15 of Set 8 | almaznyy
# Processing Record 16 of Set 8 | quang ngai
# Processing Record 17 of Set 8 | les cayes
# Processing Record 18 of Set 8 | mahanoro
# Processing Record 19 of Set 8 | madimba
# Processing Record 20 of Set 8 | teknaf
# Processing Record 21 of Set 8 | bandarbeyla
# Processing Record 22 of Set 8 | aklavik
# Processing Record 23 of Set 8 | dutse
# Processing Record 24 of Set 8 | moose factory
# Processing Record 25 of Set 8 | san cristobal
# Processing Record 26 of Set 8 | santa maria
# Processing Record 27 of Set 8 | ancud
# Processing Record 28 of Set 8 | lethem
# Processing Record 29 of Set 8 | kuzino
# Processing Record 30 of Set 8 | yenagoa
# Processing Record 31 of Set 8 | walvis bay
# Processing Record 32 of Set 8 | jahrom
# City not found. Skipping
# Processing Record 33 of Set 8 | olavarria
# Processing Record 34 of Set 8 | morgan city
# Processing Record 35 of Set 8 | saskylakh
# Processing Record 36 of Set 8 | necocli
# Processing Record 37 of Set 8 | diego de almagro
# Processing Record 38 of Set 8 | mehamn
# Processing Record 39 of Set 8 | nakamura
# Processing Record 40 of Set 8 | snasa
# Processing Record 41 of Set 8 | niquero
# Processing Record 42 of Set 8 | ustye
# Processing Record 43 of Set 8 | whitehorse
# Processing Record 44 of Set 8 | juneau
# Processing Record 45 of Set 8 | beian
# Processing Record 46 of Set 8 | tawnat
# City not found. Skipping
# Processing Record 47 of Set 8 | roald
# Processing Record 48 of Set 8 | mount pleasant
# Processing Record 49 of Set 8 | haines junction
# Processing Record 50 of Set 8 | tabiauea
# City not found. Skipping
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | kurumkan
# Processing Record 3 of Set 9 | dobsina
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | malwan
# City not found. Skipping
# Processing Record 6 of Set 9 | nuuk
# Processing Record 7 of Set 9 | keningau
# Processing Record 8 of Set 9 | amurzet
# Processing Record 9 of Set 9 | samusu
# City not found. Skipping
# Processing Record 10 of Set 9 | forio
# Processing Record 11 of Set 9 | alihe
# Processing Record 12 of Set 9 | kropotkin
# Processing Record 13 of Set 9 | biloxi
# Processing Record 14 of Set 9 | aflu
# City not found. Skipping
# Processing Record 15 of Set 9 | revda
# Processing Record 16 of Set 9 | naro moru
# Processing Record 17 of Set 9 | svetlogorsk
# Processing Record 18 of Set 9 | shimanovsk
# Processing Record 19 of Set 9 | barbar
# City not found. Skipping
# Processing Record 20 of Set 9 | la moncada
# Processing Record 21 of Set 9 | inuvik
# Processing Record 22 of Set 9 | beira
# Processing Record 23 of Set 9 | vila
# Processing Record 24 of Set 9 | mazyr
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | tessalit
# Processing Record 27 of Set 9 | portland
# Processing Record 28 of Set 9 | houlung
# City not found. Skipping
# Processing Record 29 of Set 9 | sitka
# Processing Record 30 of Set 9 | prieska
# Processing Record 31 of Set 9 | mana
# Processing Record 32 of Set 9 | kathmandu
# Processing Record 33 of Set 9 | saint-augustin
# Processing Record 34 of Set 9 | kaeo
# Processing Record 35 of Set 9 | aketi
# Processing Record 36 of Set 9 | crestview
# Processing Record 37 of Set 9 | mount gambier
# Processing Record 38 of Set 9 | kisangani
# Processing Record 39 of Set 9 | talcahuano
# Processing Record 40 of Set 9 | tarata
# Processing Record 41 of Set 9 | tayu
# Processing Record 42 of Set 9 | sidmouth
# Processing Record 43 of Set 9 | iskateley
# Processing Record 44 of Set 9 | kautokeino
# Processing Record 45 of Set 9 | sentyabrskiy
# City not found. Skipping
# Processing Record 46 of Set 9 | esperance
# Processing Record 47 of Set 9 | dorado
# Processing Record 48 of Set 9 | lao cai
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | oistins
# Processing Record 1 of Set 10 | pisco
# Processing Record 2 of Set 10 | aloleng
# Processing Record 3 of Set 10 | champerico
# Processing Record 4 of Set 10 | filingue
# Processing Record 5 of Set 10 | hellin
# Processing Record 6 of Set 10 | shangzhi
# Processing Record 7 of Set 10 | zwedru
# Processing Record 8 of Set 10 | la paz
# Processing Record 9 of Set 10 | petrolandia
# City not found. Skipping
# Processing Record 10 of Set 10 | wanaka
# Processing Record 11 of Set 10 | barghat
# Processing Record 12 of Set 10 | la palma
# Processing Record 13 of Set 10 | antalaha
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | bonavista
# Processing Record 18 of Set 10 | oriximina
# Processing Record 19 of Set 10 | luwuk
# Processing Record 20 of Set 10 | kvitok
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | auki
# Processing Record 23 of Set 10 | gigmoto
# Processing Record 24 of Set 10 | natchez
# Processing Record 25 of Set 10 | tkibuli
# Processing Record 26 of Set 10 | guane
# Processing Record 27 of Set 10 | oranjemund
# Processing Record 28 of Set 10 | lipari
# Processing Record 29 of Set 10 | letlhakane
# Processing Record 30 of Set 10 | el tarra
# Processing Record 31 of Set 10 | yumen
# Processing Record 32 of Set 10 | hervey bay
# Processing Record 33 of Set 10 | juifang
# City not found. Skipping
# Processing Record 34 of Set 10 | prabumulih
# Processing Record 35 of Set 10 | brownwood
# Processing Record 36 of Set 10 | matara
# Processing Record 37 of Set 10 | saryshagan
# City not found. Skipping
# Processing Record 38 of Set 10 | quatre cocos
# Processing Record 39 of Set 10 | pa sang
# Processing Record 40 of Set 10 | maine-soroa
# Processing Record 41 of Set 10 | sobolevo
# Processing Record 42 of Set 10 | lahad datu
# Processing Record 43 of Set 10 | weligama
# Processing Record 44 of Set 10 | qasigiannguit
# Processing Record 45 of Set 10 | weatherford
# Processing Record 46 of Set 10 | rafsanjan
# Processing Record 47 of Set 10 | zambezi
# Processing Record 48 of Set 10 | bognor regis
# Processing Record 49 of Set 10 | pasni
# Processing Record 50 of Set 10 | cepari
# Processing Record 1 of Set 11 | khorramshahr
# Processing Record 2 of Set 11 | duku
# Processing Record 3 of Set 11 | biltine
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | ciras
# City not found. Skipping
# Processing Record 6 of Set 11 | westport
# Processing Record 7 of Set 11 | meadow lake
# Processing Record 8 of Set 11 | aldama
# Processing Record 9 of Set 11 | irituia
# Processing Record 10 of Set 11 | bayanday
# Processing Record 11 of Set 11 | renqiu
# Processing Record 12 of Set 11 | tumannyy
# City not found. Skipping
# Processing Record 13 of Set 11 | kangaba
# Processing Record 14 of Set 11 | riyadh
# Processing Record 15 of Set 11 | turbat
# Processing Record 16 of Set 11 | marsh harbour
# Processing Record 17 of Set 11 | artyk
# City not found. Skipping
# Processing Record 18 of Set 11 | bereda
# Processing Record 19 of Set 11 | port keats
# Processing Record 20 of Set 11 | qiryat yam
# Processing Record 21 of Set 11 | coracao de jesus
# Processing Record 22 of Set 11 | guilin
# Processing Record 23 of Set 11 | camocim
# Processing Record 24 of Set 11 | zlobin
# Processing Record 25 of Set 11 | guerrero negro
# Processing Record 26 of Set 11 | rio gallegos
# Processing Record 27 of Set 11 | uyo
# Processing Record 28 of Set 11 | russell
# Processing Record 29 of Set 11 | sumbe
# Processing Record 30 of Set 11 | harper
# Processing Record 31 of Set 11 | gairo
# Processing Record 32 of Set 11 | suntar
# Processing Record 33 of Set 11 | chumikan
# Processing Record 34 of Set 11 | pascagoula
# Processing Record 35 of Set 11 | turtkul
# City not found. Skipping
# Processing Record 36 of Set 11 | mabaruma
# Processing Record 37 of Set 11 | maumere
# Processing Record 38 of Set 11 | ouallam
# Processing Record 39 of Set 11 | sabzevar
# Processing Record 40 of Set 11 | olafsvik
# Processing Record 41 of Set 11 | vesyegonsk
# Processing Record 42 of Set 11 | pathein
# Processing Record 43 of Set 11 | vanavara
# Processing Record 44 of Set 11 | kralendijk
# Processing Record 45 of Set 11 | tortoli
# Processing Record 46 of Set 11 | paamiut
# Processing Record 47 of Set 11 | posse
# Processing Record 48 of Set 11 | nizwa
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | victoria
# Processing Record 1 of Set 12 | nueva italia
# Processing Record 2 of Set 12 | port moresby
# Processing Record 3 of Set 12 | umm lajj
# Processing Record 4 of Set 12 | appleton
# Processing Record 5 of Set 12 | coihaique
# Processing Record 6 of Set 12 | iralaya
# Processing Record 7 of Set 12 | grand river south east
# City not found. Skipping
# Processing Record 8 of Set 12 | willmar
# Processing Record 9 of Set 12 | porto santo
# Processing Record 10 of Set 12 | broken hill
# Processing Record 11 of Set 12 | zaozerne
# Processing Record 12 of Set 12 | richards bay
# Processing Record 13 of Set 12 | klyuchi
# Processing Record 14 of Set 12 | coquimbo
# Processing Record 15 of Set 12 | abha
# Processing Record 16 of Set 12 | lavrentiya
# Processing Record 17 of Set 12 | lichinga
# Processing Record 18 of Set 12 | zhitikara
# City not found. Skipping
# Processing Record 19 of Set 12 | letterkenny
# Processing Record 20 of Set 12 | ampanihy
# Processing Record 21 of Set 12 | terrace
# Processing Record 22 of Set 12 | vila real de santo antonio
# Processing Record 23 of Set 12 | port shepstone
# Processing Record 24 of Set 12 | santa marta
# Processing Record 25 of Set 12 | matagami
# Processing Record 26 of Set 12 | nacala
# Processing Record 27 of Set 12 | balotra
# Processing Record 28 of Set 12 | ureki
# Processing Record 29 of Set 12 | saravena
# Processing Record 30 of Set 12 | anchorage
# Processing Record 31 of Set 12 | coahuayana
# Processing Record 32 of Set 12 | andijon
# Processing Record 33 of Set 12 | lasa
# Processing Record 34 of Set 12 | belmonte
# Processing Record 35 of Set 12 | wawa
# Processing Record 36 of Set 12 | staroye drozhzhanoye
# Processing Record 37 of Set 12 | tatawin
# Processing Record 38 of Set 12 | tezu
# Processing Record 39 of Set 12 | cayenne
# Processing Record 40 of Set 12 | nikel
# Processing Record 41 of Set 12 | ulladulla
# Processing Record 42 of Set 12 | varzea da palma
# Processing Record 43 of Set 12 | viedma
# Processing Record 44 of Set 12 | millinocket
# Processing Record 45 of Set 12 | srivardhan
# Processing Record 46 of Set 12 | byron bay
# Processing Record 47 of Set 12 | escarcega
# Processing Record 48 of Set 12 | barwaha
# City not found. Skipping
# Processing Record 49 of Set 12 | srednekolymsk
# Processing Record 50 of Set 12 | villarrica
# Processing Record 1 of Set 13 | aasiaat
# Processing Record 2 of Set 13 | yerbogachen
# Processing Record 3 of Set 13 | den helder
# Processing Record 4 of Set 13 | lakes entrance
# Processing Record 5 of Set 13 | chernyshevskiy
# Processing Record 6 of Set 13 | saurimo
# Processing Record 7 of Set 13 | ubauro
# Processing Record 8 of Set 13 | smidovich
# Processing Record 9 of Set 13 | san patricio
# Processing Record 10 of Set 13 | cockburn town
# Processing Record 11 of Set 13 | natchitoches
# Processing Record 12 of Set 13 | karkaralinsk
# City not found. Skipping
# Processing Record 13 of Set 13 | bouca
# Processing Record 14 of Set 13 | zaysan
# Processing Record 15 of Set 13 | nishihara
# Processing Record 16 of Set 13 | smithers
# Processing Record 17 of Set 13 | karakendzha
# City not found. Skipping
# Processing Record 18 of Set 13 | caconda
# Processing Record 19 of Set 13 | fort morgan
# Processing Record 20 of Set 13 | kayerkan
# Processing Record 21 of Set 13 | mbanza-ngungu
# Processing Record 22 of Set 13 | jalingo
# Processing Record 23 of Set 13 | bendigo
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | cheb
# Processing Record 26 of Set 13 | camacha
# Processing Record 27 of Set 13 | touros
# Processing Record 28 of Set 13 | sao joao da barra
# Processing Record 29 of Set 13 | lulea
# Processing Record 30 of Set 13 | mackay
# Processing Record 31 of Set 13 | sehithwa
# Processing Record 32 of Set 13 | abu zabad
# Processing Record 33 of Set 13 | ivanjica
# Processing Record 34 of Set 13 | turukhansk
# Processing Record 35 of Set 13 | ferme-neuve
# Processing Record 36 of Set 13 | suhbaatar
# Processing Record 37 of Set 13 | mapiri
# Processing Record 38 of Set 13 | fredericton
# Processing Record 39 of Set 13 | vengerovo
# Processing Record 40 of Set 13 | kano
# Processing Record 41 of Set 13 | bela
# Processing Record 42 of Set 13 | yakima
# Processing Record 43 of Set 13 | longlac
# City not found. Skipping
# Processing Record 44 of Set 13 | khonuu
# City not found. Skipping
# Processing Record 45 of Set 13 | novo aripuana
# Processing Record 46 of Set 13 | puerto carreno
# Processing Record 47 of Set 13 | magdagachi
# Processing Record 48 of Set 13 | asau
# Processing Record 49 of Set 13 | ponta do sol
# Processing Record 50 of Set 13 | toba
# Processing Record 1 of Set 14 | tres arroyos
# Processing Record 2 of Set 14 | key west
# Processing Record 3 of Set 14 | alofi
# Processing Record 4 of Set 14 | pemba
# Processing Record 5 of Set 14 | bouna
# Processing Record 6 of Set 14 | pilar
# Processing Record 7 of Set 14 | vredendal
# Processing Record 8 of Set 14 | ekibastuz
# Processing Record 9 of Set 14 | castro-urdiales
# Processing Record 10 of Set 14 | kangaatsiaq
# Processing Record 11 of Set 14 | viligili
# City not found. Skipping
# Processing Record 12 of Set 14 | wasilla
# Processing Record 13 of Set 14 | sioux lookout
# Processing Record 14 of Set 14 | ishigaki
# Processing Record 15 of Set 14 | ariquemes
# Processing Record 16 of Set 14 | yar-sale
# Processing Record 17 of Set 14 | shar
# Processing Record 18 of Set 14 | necochea
# Processing Record 19 of Set 14 | ituni
# City not found. Skipping
# Processing Record 20 of Set 14 | turtas
# Processing Record 21 of Set 14 | kholodnyy
# Processing Record 22 of Set 14 | costa rica
# Processing Record 23 of Set 14 | liberal
# Processing Record 24 of Set 14 | ewa beach
# Processing Record 25 of Set 14 | boyuibe
# Processing Record 26 of Set 14 | basoko
# Processing Record 27 of Set 14 | venado tuerto
# Processing Record 28 of Set 14 | kathu
# Processing Record 29 of Set 14 | sisimiut
# Processing Record 30 of Set 14 | kirn
# Processing Record 31 of Set 14 | la ronge
# Processing Record 32 of Set 14 | leh
# Processing Record 33 of Set 14 | senador jose porfirio
# Processing Record 34 of Set 14 | ostersund
# Processing Record 35 of Set 14 | varnavino
# Processing Record 36 of Set 14 | gamba
# Processing Record 37 of Set 14 | ayame
# Processing Record 38 of Set 14 | tomatlan
# Processing Record 39 of Set 14 | virginia beach
# Processing Record 40 of Set 14 | mbale
# Processing Record 41 of Set 14 | boralday
# Processing Record 42 of Set 14 | slave lake
# Processing Record 43 of Set 14 | sinjar
# Processing Record 44 of Set 14 | masuri
# Processing Record 45 of Set 14 | hami
# Processing Record 46 of Set 14 | sandnessjoen
# Processing Record 47 of Set 14 | camana
# Processing Record 48 of Set 14 | marsa matruh
# Processing Record 49 of Set 14 | quelimane
# Processing Record 50 of Set 14 | teeli
# Processing Record 1 of Set 15 | north augusta
# Processing Record 2 of Set 15 | conde
# Processing Record 3 of Set 15 | sampit
# Processing Record 4 of Set 15 | thohoyandou
# Processing Record 5 of Set 15 | narimanov
# Processing Record 6 of Set 15 | pampas
# Processing Record 7 of Set 15 | ede
# Processing Record 8 of Set 15 | monrovia
# Processing Record 9 of Set 15 | bure
# Processing Record 10 of Set 15 | bayan
# Processing Record 11 of Set 15 | pueblo nuevo
# Processing Record 12 of Set 15 | beloha
# Processing Record 13 of Set 15 | arlit
# Processing Record 14 of Set 15 | constitucion
# Processing Record 15 of Set 15 | eyl
# Processing Record 16 of Set 15 | salvador
# Processing Record 17 of Set 15 | palm springs
# Processing Record 18 of Set 15 | road town
# Processing Record 19 of Set 15 | christchurch
# Processing Record 20 of Set 15 | muisne
# Processing Record 21 of Set 15 | pemangkat
# Processing Record 22 of Set 15 | kirksville
# Processing Record 23 of Set 15 | kitui
# Processing Record 24 of Set 15 | port hawkesbury
# Processing Record 25 of Set 15 | kasongo-lunda
# Processing Record 26 of Set 15 | baton rouge
# Processing Record 27 of Set 15 | notre-dame-du-lac
# Processing Record 28 of Set 15 | kununurra
# Processing Record 29 of Set 15 | mnogovershinnyy
# Processing Record 30 of Set 15 | boulder city
# Processing Record 31 of Set 15 | qaqortoq
# Processing Record 32 of Set 15 | abu kamal
# Processing Record 33 of Set 15 | bismarck
# Processing Record 34 of Set 15 | kailua
# Processing Record 35 of Set 15 | kitami
# Processing Record 36 of Set 15 | bowen
# Processing Record 37 of Set 15 | karaul
# City not found. Skipping
# Processing Record 38 of Set 15 | manturovo
# Processing Record 39 of Set 15 | gornopravdinsk
# Processing Record 40 of Set 15 | conceicao do araguaia
# Processing Record 41 of Set 15 | gannan
# Processing Record 42 of Set 15 | tafresh
# Processing Record 43 of Set 15 | xining
# Processing Record 44 of Set 15 | pedro ii
# Processing Record 45 of Set 15 | socorro
# Processing Record 46 of Set 15 | saint-pierre
# Processing Record 47 of Set 15 | laguna de perlas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Create CSV file of DF
csv_weather_file = "Weather_Database/weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
